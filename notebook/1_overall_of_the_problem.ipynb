# %% [markdown]
# # Checklist
# 1. Frame the problem and look at the picture. (จัดลำดับ หุ้นน่าซื้อ โดยใช้วิธีคิดแบบ [value investing](https://docs.google.com/spreadsheets/d/1zcPrkgBKzuZTNmR8287a-5mzu2yuAYNUavkUUu_-dbA/edit#gid=1256847632) ที่เคยศึกษามา + กวี ชูกิตเกษม เน้นวิเคราะห์จากงบการเงิน))
# 2. Get the data. (Data Excel + Get เพิ่มจาก Settrade & SET)
# 3. Explore the data to gain the insights.
# 4. Prepare the data to better expose the underlying data patterns ti ML algorithm.
# 5. Explore Many Model and combine them into a great solution
# 6. Fine-tune your models.
# 7. Present your solution.
# 8. Launch, monitor.

# %% [markdown]
# - ทบทวนความรู้เดิมว่าอะไรยังไง
# - ดู "เทคนิคการหาหุ้น และการประเมินราคาหุ้น โดย คุณกวี ชูกิจเกษม รอง MD บล.กสิกรไทย" https://pantip.com/topic/32254613

# %% [markdown]
# - Long Term ดูผลข้อมูลเป็นแบบรายปี (ลดความผันผวน)

# %% [markdown]
# Data Ingestion
# - http://www.patanasongsivilai.com/blog/stock-thai-python/

# %% [markdown]
# - ออกแบบ DB ว่าจะเก็บข้อมูลหุ้นอะไรยังไงบ้าง กี่ตาราง จากงบการเงินรายวัน (แล้วค่อยมา Groupเป็น รายปี, รายQ ใน report เอง)
# - ราคาสรุปรายวันเอาไว้มองภาพรวม ทำ model สายเทคนิคในอนาคต
# - ดึงข้อมูลงบการเงินจาก SET มาเก็บลง DB วันละครั้ง (ตีสอง) ดึงไม่ได้มีแจ้งเตือน
# - ดึงราคาหุ้นปัจจุบันมา เปรียบเทียบกับราคาหุ้นที่เราคำนวณได้ ถ้าถูกสีเขียว แพงมากสีแดง
# - Algo คิด ได้รายชื่อหุ้นดีพร้อมราคาที่น่าซื้อ

# %% [markdown]
# ข้อมูลจาก Google Finance Delay 15 นาที

# %% [markdown]
# เริ่มเก็บข้อมูลตั้งแต่วันที่ 1 May 2018

# %%
from googlefinance.client import get_price_data, get_prices_data, get_prices_time_data

# Dow Jones
param = {
	'q': "SET", # Stock symbol (ex: "AAPL")
	'i': "86400", # Interval size in seconds ("86400" = 1 day intervals)
	'x': "INDEXBKK", # Stock exchange symbol on which stock is traded (ex: "NASD")
	'p': "1Y" # Period (Ex: "1Y" = 1 year)
}
# get price data (return pandas dataframe)
df = get_price_data(param)
print(df)
# Out:
#                         Open     High      Low    Close      Volume
# 2017-04-21 16:40:00  1569.90  1573.39  1567.55  1570.02  3838577451
# 2017-04-24 16:40:00  1571.16  1572.77  1562.20  1564.66  4020780322
# 2017-04-25 16:40:00  1567.50  1569.90  1553.44  1562.27  4189889665
# 2017-04-26 16:40:00  1562.32  1569.10  1559.64  1567.47  4182995249
# 2017-04-27 16:40:00  1566.83  1569.36  1563.58  1566.77  3400807948
# 2017-04-28 16:40:00  1568.56  1569.12  1562.82  1566.32  3390950502
# 2017-05-02 16:40:00  1566.59  1570.07  1563.91  1564.12  2730582335
# 2017-05-03 16:40:00  1565.66  1569.51  1563.20  1564.12  3073715439
# 2017-05-04 16:40:00  1565.77  1574.38  1565.59  1573.05  3177495132
# 2017-05-05 16:40:00  1570.70  1571.80  1563.95  1569.02  3110398917
# 2017-05-08 16:40:00  1568.00  1571.42  1565.74  1568.02  2866335867
# 2017-05-09 16:40:00  1570.61  1571.08  1557.60  1560.31  3826444737
# 2017-05-11 16:40:00  1562.89  1564.31  1546.81  1550.27  4838608088
# ...
